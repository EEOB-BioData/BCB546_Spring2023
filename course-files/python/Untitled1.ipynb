# %%
conda install pandas
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.read_csv("surveys.csv") # read.table, read.csv
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df = pd.read_csv("surveys.csv")
# print(surveys_df)

#type(surveys_df)
surveys_df.__class__
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.tail(5)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df.shape
# Out:
# tuple

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
species_id = pd.unique(surveys_df['species_id'])
print(len(species_id))
# Out:
# 49

# %%
plot_names = pd.unique(surveys_df['plot_id'])
len(plot_names)
# Out:
# 24

# %%
print(surveys_df['plot_id'].nunique())
# Out:
# 24

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['year'].describe()
# Out:
# count    35549.000000
# mean      1990.475231
# std          7.493355
# min       1977.000000
# 25%       1984.000000
# 50%       1990.000000
# 75%       1997.000000
# max       2002.000000
# Name: year, dtype: float64

# %%
surveys_df['weight'].max()
# Out:
# 280.0

# %%
sorted_data = surveys_df.groupby('sex')
sorted_data['weight'].describe()
# sorted_data['weight'] == sorted_data$weight
# Out:
#        count       mean        std  min   25%   50%   75%    max
# sex
# F    15303.0  42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    16879.0  42.995379  36.184981  4.0  20.0  39.0  49.0  280.0

# %%
sorted_data = surveys_df.groupby(['sex', 'plot_id'])
sorted_data.count()
# Out:
#              record_id  month   day  year  species_id  hindfoot_length  weight
# sex plot_id
# F   1              848    848   848   848         848              808     826
#     2              970    970   970   970         970              918     954
#     3              893    893   893   893         893              863     873
#     4              872    872   872   872         872              835     850
#     5              527    527   527   527         527              499     516
#     6              737    737   737   737         737              696     721
#     7              335    335   335   335         335              313     326
#     8              840    840   840   840         840              805     817
#     9              853    853   853   853         853              801     823
#     10             141    141   141   141         141              134     138
#     11             822    822   822   822         822              785     796
# ...

# %%
sorted_data.median()
# Out:
# /var/folders/rd/6m0c9yzn1397p69skf64yy9w0000gn/T/ipykernel_97508/3905321541.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sorted_data.median()
#      record_id  month   day    year  plot_id  hindfoot_length  weight
# sex
# F      18075.5    7.0  16.0  1990.0     12.0             27.0    34.0
# M      17727.5    6.0  16.0  1990.0     11.0             34.0    39.0

# %%
sub_df = sorted_data['weight'].describe()
sub_df['count']
# Out:
# sex
# F    15303.0
# M    16879.0
# Name: count, dtype: float64

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
species_counts
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
sort_by_species = surveys_df.groupby('species_id')
species_by_record = sort_by_species['record_id']
species_by_record.count()
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
import numpy as np
double_weight = np.log(surveys_df['weight'])

print(double_weight)
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 35544         NaN
# 35545         NaN
# 35546    2.639057
# 35547    3.931826
# 35548         NaN
# Name: weight, Length: 35549, dtype: float64

# %%
surveys_df['weight'].head(10)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: weight, dtype: float64

# %%
species_counts.plot(kind='bar',title='Number of individuals per species')
# Out:
# <Axes: title={'center': 'Number of individuals per species'}, xlabel='species_id'>

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/wade/anaconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     matplotlib-3.7.1           |  py310hecd8cb5_1           9 KB
#     matplotlib-base-3.7.1      |  py310ha533b9c_1         6.7 MB
#     ------------------------------------------------------------
#                                            Total:         6.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/osx-64::brotli-1.0.9-hca72f7f_7
#   brotli-bin         pkgs/main/osx-64::brotli-bin-1.0.9-hca72f7f_7
#   contourpy          pkgs/main/osx-64::contourpy-1.0.5-py310haf03e11_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
# ...

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()

# %%
total_count.plot(kind='bar',title='Number captured per plot', color='green')
# Out:
# <Axes: title={'center': 'Number captured per plot'}, xlabel='plot_id'>

# %%
by_plot_sex = surveys_df.groupby(['plot_id','sex'])
plot_sex_count = by_plot_sex['weight'].sum()
plot_sex_count
# Out:
# plot_id  sex
# 1        F      38253.0
#          M      59979.0
# 2        F      50144.0
#          M      57250.0
# 3        F      27251.0
#          M      28253.0
# 4        F      39796.0
#          M      49377.0
# 5        F      21143.0
#          M      23326.0
# 6        F      26210.0
#          M      27245.0
# 7        F       6522.0
#          M       6422.0
# 8        F      37274.0
#          M      47755.0
# 9        F      44128.0
#          M      48727.0
# 10       F       2359.0
#          M       2776.0
# 11       F      34638.0
#          M      43106.0
# 12       F      51825.0
#          M      57420.0
# 13       F      24720.0
#          M      30354.0
# 14       F      32770.0
#          M      46469.0
# 15       F      12455.0
#          M      11037.0
# 16       F       5446.0
#          M       6310.0
# 17       F      42106.0
#          M      48082.0
# 18       F      27353.0
#          M      26433.0
# 19       F      11297.0
# ...

# %%
plot_sex_count.unstack()
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %%
spc = plot_sex_count.unstack()
s_plot = spc.plot(kind='bar',stacked=True,title="Total weight by plot and sex")
s_plot.set_ylabel("Weight (g)")
s_plot.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')
